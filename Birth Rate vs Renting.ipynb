# %%
# %matplotlib notebook

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
fertility_rate_path= 'Documents/fertility_rate.csv'
births_by_Month_path = 'Documents/Live_births_by_Month.csv'
world_Rates_path ='Documents/World Crude Birth Rates.csv'

fertility_rate = pd.read_csv(fertility_rate_path)
births_by_month = pd.read_csv(births_by_Month_path)

# %%
fertility_rate
# Out:
#          Country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0         _World  4.98  5.00  5.03  5.05  5.06  5.04  4.99  4.97  4.92  ...
# 1    Afghanistan  7.45  7.45  7.45  7.45  7.45  7.45  7.45  7.45  7.45  ...
# 2        Albania  6.49  6.40  6.28  6.13  5.96  5.77  5.58  5.39  5.22  ...
# 3        Algeria  7.52  7.57  7.61  7.65  7.67  7.68  7.68  7.67  7.67  ...
# 4         Angola  6.71  6.79  6.87  6.95  7.04  7.12  7.19  7.27  7.33  ...
# ..           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 182    Venezuela  6.36  6.30  6.23  6.16  6.07  5.98  5.87  5.75  5.61  ...
# 183      Vietnam  6.35  6.39  6.43  6.45  6.46  6.48  6.49  6.49  6.49  ...
# 184        Yemen  7.94  7.96  7.99  8.03  8.07  8.11  8.17  8.22  8.28  ...
# 185       Zambia  7.12  7.17  7.21  7.25  7.27  7.29  7.30  7.32  7.33  ...
# 186     Zimbabwe  7.16  7.22  7.27  7.31  7.35  7.37  7.39  7.40  7.41  ...
#
# ...

# %%
national_birth_rate = fertility_rate.loc[fertility_rate["Country"] == "Canada", :]
national_birth_rate
# Out:
#    Country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  2011  \
# 33  Canada  3.81  3.75  3.68  3.61  3.46  3.12  2.75  2.53  2.39  ...  1.62
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020
# 33  1.62   1.6  1.61   1.6  1.59  1.54   1.5  1.47   1.4
#
# [1 rows x 62 columns]

# %%
pd.melt(national_birth_rate)
# Out:
#    variable   value
# 0   Country  Canada
# 1      1960    3.81
# 2      1961    3.75
# 3      1962    3.68
# 4      1963    3.61
# ..      ...     ...
# 57     2016    1.59
# 58     2017    1.54
# 59     2018     1.5
# 60     2019    1.47
# 61     2020     1.4
#
# [62 rows x 2 columns]

# %%
year =  national_birth_rate.loc('value')
birth_rate = national_birth_rate.loc('variable')

plt.bar(national_birth_rate, height=1)
plt.title('Fertility rate of Canada from 1960-2020')
plt.plot(birth_rate, year)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     549         try:
# --> 550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
#
# KeyError: 'value'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1588\3026404635.py in <module>
# ----> 1 year =  national_birth_rate.loc('value')
#       2 birth_rate = national_birth_rate.loc('variable')
#       3
#       4 plt.bar(national_birth_rate, height=1)
#       5 plt.title('Fertility rate of Canada from 1960-2020')
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     632
#     633         if axis is not None:
# ...
