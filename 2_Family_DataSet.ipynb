# %%
import pandas as pd

# %% [markdown]
# ## Clean Dataset for Wife Contribution to family earnings

# %%
wifemoneyfilepath=r"C:\Users\Eleshia\Desktop\DA Boot Camp\Project1\DataSets\WifeContributionMoney.csv"
wifemoneydf=pd.read_csv(wifemoneyfilepath)
wifemoneydf
# Out:
# C:\Users\Eleshia\AppData\Local\Temp\ipykernel_35608\3652118033.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   wifemoneydf=pd.read_csv(wifemoneyfilepath)
#         REF_DATE                                          GEO           DGUID  \
# 0           2000                                       Canada  2016A000011124
# 1           2000                                       Canada  2016A000011124
# 2           2000                                       Canada  2016A000011124
# 3           2000                                       Canada  2016A000011124
# 4           2000                                       Canada  2016A000011124
# ...          ...                                          ...             ...
# 298115      2020  Lloydminster, combined Alberta/Saskatchewan    2016S0504840
# 298116      2020  Lloydminster, combined Alberta/Saskatchewan    2016S0504840
# ...

# %%
wifemoneydf.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID',
#        'Wife's contribution to husband-wife family employment income',
#        'Husband-wife families', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID',
#        'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED',
#        'DECIMALS'],
#       dtype='object')

# %%
wmdf=wifemoneydf.rename(columns={
    
'REF_DATE':'Year', 'GEO':"Location",
       "Wife's contribution to husband-wife family employment income":"Wife Contribution",
       'Husband-wife families':"Husband and Wife Family"})
wmdf.head()
# Out:
#    Year Location           DGUID  \
# 0  2000   Canada  2016A000011124
# 1  2000   Canada  2016A000011124
# 2  2000   Canada  2016A000011124
# 3  2000   Canada  2016A000011124
# 4  2000   Canada  2016A000011124
#
#                                    Wife Contribution  \
# 0  Number of husband-wife families with employmen...
# 1  Number of husband-wife families with employmen...
# 2  Number of husband-wife families with employmen...
# 3  Number of husband-wife families with employmen...
# 4  Number of husband-wife families with employmen...
#
#                          Husband and Wife Family     UOM  UOM_ID  \
# 0                    Total husband-wife families  Number     223
# 1         Husband-wife families with no children  Number     223
# 2             Husband-wife families with 1 child  Number     223
# 3          Husband-wife families with 2 children  Number     223
# 4  Husband-wife families with 3 or more children  Number     223
#
# ...

# %%
wmdf.dtypes
# Out:
# Year                         int64
# Location                    object
# DGUID                       object
# Wife Contribution           object
# Husband and Wife Family     object
# UOM                         object
# UOM_ID                       int64
# SCALAR_FACTOR               object
# SCALAR_ID                    int64
# VECTOR                      object
# COORDINATE                  object
# VALUE                      float64
# STATUS                      object
# SYMBOL                     float64
# TERMINATED                  object
# DECIMALS                     int64
# dtype: object

# %%
wmdf.columns
# Out:
# Index(['Year', 'Location', 'DGUID', 'Wife Contribution',
#        'Husband and Wife Family', 'UOM', 'UOM_ID', 'SCALAR_FACTOR',
#        'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL',
#        'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
wifedf=wmdf.loc[:, ['Year', 'Location', 'Wife Contribution',
       'Husband and Wife Family', 'VALUE']]
wifedf.head()
# Out:
#    Year Location                                  Wife Contribution  \
# 0  2000   Canada  Number of husband-wife families with employmen...
# 1  2000   Canada  Number of husband-wife families with employmen...
# 2  2000   Canada  Number of husband-wife families with employmen...
# 3  2000   Canada  Number of husband-wife families with employmen...
# 4  2000   Canada  Number of husband-wife families with employmen...
#
#                          Husband and Wife Family      VALUE
# 0                    Total husband-wife families  5723830.0
# 1         Husband-wife families with no children  2202840.0
# 2             Husband-wife families with 1 child  1340750.0
# 3          Husband-wife families with 2 children  1497950.0
# 4  Husband-wife families with 3 or more children   682290.0

# %%
finalwifedf=wifedf.set_index('Year')
finalwifedf
# Out:
#                                          Location  \
# Year
# 2000                                       Canada
# 2000                                       Canada
# 2000                                       Canada
# 2000                                       Canada
# 2000                                       Canada
# ...                                           ...
# 2020  Lloydminster, combined Alberta/Saskatchewan
# 2020  Lloydminster, combined Alberta/Saskatchewan
# 2020  Lloydminster, combined Alberta/Saskatchewan
# 2020  Lloydminster, combined Alberta/Saskatchewan
# 2020  Lloydminster, combined Alberta/Saskatchewan
#
#                                       Wife Contribution  \
# Year
# 2000  Number of husband-wife families with employmen...
# 2000  Number of husband-wife families with employmen...
# 2000  Number of husband-wife families with employmen...
# 2000  Number of husband-wife families with employmen...
# 2000  Number of husband-wife families with employmen...
# ...

# %%
finalwifedf['Location'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador',
#        "St. John's, Newfoundland and Labrador", 'Prince Edward Island',
#        'Nova Scotia', 'Halifax, Nova Scotia', 'New Brunswick',
#        'Saint John, New Brunswick', 'Quebec', 'Saguenay, Quebec',
#        'Québec, Quebec', 'Sherbrooke, Quebec', 'Trois-Rivières, Quebec',
#        'Montréal, Quebec', 'Ottawa-Gatineau, Quebec part', 'Ontario',
#        'Ottawa-Gatineau, Ontario part', 'Oshawa, Ontario',
#        'Toronto, Ontario', 'Hamilton, Ontario',
#        'St. Catharines-Niagara, Ontario',
#        'Kitchener-Cambridge-Waterloo, Ontario', 'London, Ontario',
#        'Windsor, Ontario', 'Greater Sudbury, Ontario',
#        'Thunder Bay, Ontario', 'Manitoba', 'Winnipeg, Manitoba',
#        'Saskatchewan', 'Regina, Saskatchewan', 'Saskatoon, Saskatchewan',
#        'Alberta', 'Calgary, Alberta', 'Edmonton, Alberta',
#        'British Columbia', 'Vancouver, British Columbia',
# ...

# %%
wife_filtered=finalwifedf[finalwifedf['Location'] == 'Ontario']
wife_filtered
# Out:
#      Location                                  Wife Contribution  \
# Year
# 2000  Ontario  Number of husband-wife families with employmen...
# 2000  Ontario  Number of husband-wife families with employmen...
# 2000  Ontario  Number of husband-wife families with employmen...
# 2000  Ontario  Number of husband-wife families with employmen...
# 2000  Ontario  Number of husband-wife families with employmen...
# ...       ...                                                ...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
#
#                                 Husband and Wife Family      VALUE
# Year
# 2000                        Total husband-wife families  2189340.0
# ...

# %%
print(wife_filtered['Husband and Wife Family'].unique())
print(wife_filtered['Wife Contribution'].unique())
# Out:
# ['Total husband-wife families' 'Husband-wife families with no children'
#  'Husband-wife families with 1 child'
#  'Husband-wife families with 2 children'
#  'Husband-wife families with 3 or more children'
#  'Husband-wife families with wives aged 0 to 24 years'
#  'Husband-wife families with wives aged 25 to 34 years'
#  'Husband-wife families with wives aged 35 to 44 years'

# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
# 2020  Ontario  Husband-wife families where the wife contribut...
#
#                     Husband and Wife Family     VALUE
# Year
# 2000  Husband-wife families with 2 children  584540.0
# 2000  Husband-wife families with 2 children   99750.0
# ...

# %%
wife_filtered.to_csv(r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Cleaned_Datasets\wife_contribution.csv",
                    encoding="Utf-8", index=True, header=True)

# %%
one_childdf.to_csv(r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Cleaned_Datasets\One Child Family.csv",
                    encoding="Utf-8", index=True, header=True)

# %%
two_childdf.to_csv(r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Cleaned_Datasets\Two Child Family.csv",
                    encoding="Utf-8", index=True, header=True)
three_childdf.to_csv(r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Cleaned_Datasets\Three or More Child Family.csv",
                    encoding="Utf-8", index=True, header=True)

# %% [markdown]
# ## Next DataSet to clean... Number of Divorces

# %%
divorcedfilepath=r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\NumberOfDivorces-Canada-39100053-eng\39100053.csv"
div_df=pd.read_csv(divorcedfilepath)
div_df.head()
# Out:
# C:\Users\Eleshia\AppData\Local\Temp\ipykernel_35608\713897073.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   div_df=pd.read_csv(divorcedfilepath)
#    REF_DATE     GEO           DGUID Sex or gender  Age at divorce  \
# 0      1970  Canada  2016A000011124    Both sexes        All ages
# 1      1970  Canada  2016A000011124    Both sexes  Under 20 years
# 2      1970  Canada  2016A000011124    Both sexes  20 to 24 years
# 3      1970  Canada  2016A000011124    Both sexes  25 to 29 years
# 4      1970  Canada  2016A000011124    Both sexes  30 to 34 years
#
#             Indicator     UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 0  Number of divorces  Number     223         units          0  v1331259403
# 1  Number of divorces  Number     223         units          0  v1331259392
# 2  Number of divorces  Number     223         units          0  v1331259393
# ...

# %%
div_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Sex or gender', 'Age at divorce',
#        'Indicator', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR',
#        'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
renamediv=div_df.rename(columns={'REF_DATE':'Year', 'GEO':'Location', 'UOM':'Unit Of Measure'})
renamediv.sample()
# Out:
#        Year Location        DGUID Sex or gender  Age at divorce  \
# 10220  1991   Quebec  2016A000224         Males  30 to 34 years
#
#                 Indicator Unit Of Measure  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 10220  Number of divorces          Number     223         units          0
#
#             VECTOR COORDINATE   VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# 10220  v1331259095    6.2.5.1  3945.0     NaN     NaN        NaN         0

# %%
newdiv_df=renamediv.set_index('Year')
newdiv_df.sample()
# Out:
#          Location        DGUID Sex or gender Age at divorce     Indicator  \
# Year
# 2003  Nova Scotia  2016A000212    Both sexes       All ages  Divorce rate
#
#                      Unit Of Measure  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# Year
# 2003  Rate per 1,000 married persons     424         units          0
#
#            VECTOR COORDINATE  VALUE  STATUS  SYMBOL TERMINATED  DECIMALS
# Year
# 2003  v1331259511    4.1.1.2    9.5     NaN     NaN        NaN         1

# %%
filtered_divorced_df=newdiv_df.loc[:,['Location','Sex or gender', 'Age at divorce',
       'Indicator','Unit Of Measure', 'VALUE' ]]
filtered_divorced_df
# Out:
#      Location Sex or gender     Age at divorce           Indicator  \
# Year
# 1970   Canada    Both sexes           All ages  Number of divorces
# 1970   Canada    Both sexes     Under 20 years  Number of divorces
# 1970   Canada    Both sexes     20 to 24 years  Number of divorces
# 1970   Canada    Both sexes     25 to 29 years  Number of divorces
# 1970   Canada    Both sexes     30 to 34 years  Number of divorces
# ...       ...           ...                ...                 ...
# 2020  Nunavut       Females     55 to 59 years        Divorce rate
# 2020  Nunavut       Females     60 to 64 years  Number of divorces
# 2020  Nunavut       Females     60 to 64 years        Divorce rate
# 2020  Nunavut       Females  65 years and over  Number of divorces
# 2020  Nunavut       Females  65 years and over        Divorce rate
#
#                      Unit Of Measure    VALUE
# Year
# 1970                          Number  58605.0
# 1970                          Number    153.0
# ...

# %%
filtered_divorced_df['Location'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon',
#        'Northwest Territories including Nunavut', 'Northwest Territories',
#        'Nunavut'], dtype=object)

# %%
Ontario_divorced=filtered_divorced_df[filtered_divorced_df['Location'] == 'Ontario']
Ontario_divorced
# Out:
#      Location Sex or gender     Age at divorce           Indicator  \
# Year
# 1970  Ontario    Both sexes           All ages  Number of divorces
# 1970  Ontario    Both sexes     Under 20 years  Number of divorces
# 1970  Ontario    Both sexes     20 to 24 years  Number of divorces
# 1970  Ontario    Both sexes     25 to 29 years  Number of divorces
# 1970  Ontario    Both sexes     30 to 34 years  Number of divorces
# ...       ...           ...                ...                 ...
# 2020  Ontario    Both sexes     55 to 59 years        Divorce rate
# 2020  Ontario    Both sexes     60 to 64 years  Number of divorces
# 2020  Ontario    Both sexes     60 to 64 years        Divorce rate
# 2020  Ontario    Both sexes  65 years and over  Number of divorces
# 2020  Ontario    Both sexes  65 years and over        Divorce rate
#
#                      Unit Of Measure    VALUE
# Year
# 1970                          Number  24012.0
# 1970                          Number     42.0
# ...

# %%
Ontario_divorced_df1=Ontario_divorced[Ontario_divorced['Age at divorce'].str.contains('^All ages$')]
Ontario_divorced_df1
# Out:
#      Location Sex or gender Age at divorce           Indicator  \
# Year
# 1970  Ontario    Both sexes       All ages  Number of divorces
# 1970  Ontario         Males       All ages  Number of divorces
# 1970  Ontario       Females       All ages  Number of divorces
# 1971  Ontario    Both sexes       All ages  Number of divorces
# 1971  Ontario         Males       All ages  Number of divorces
# ...       ...           ...            ...                 ...
# 2018  Ontario    Both sexes       All ages        Divorce rate
# 2019  Ontario    Both sexes       All ages  Number of divorces
# 2019  Ontario    Both sexes       All ages        Divorce rate
# 2020  Ontario    Both sexes       All ages  Number of divorces
# 2020  Ontario    Both sexes       All ages        Divorce rate
#
#                      Unit Of Measure    VALUE
# Year
# 1970                          Number  24012.0
# 1970                          Number  12006.0
# 1970                          Number  12006.0
# ...

# %%
Ontario_divorced_df2=Ontario_divorced_df1[Ontario_divorced_df1['Indicator'].str.contains('^Number of divorces$')]
Ontario_divorced_df2
# Out:
#      Location Sex or gender Age at divorce           Indicator  \
# Year
# 1970  Ontario    Both sexes       All ages  Number of divorces
# 1970  Ontario         Males       All ages  Number of divorces
# 1970  Ontario       Females       All ages  Number of divorces
# 1971  Ontario    Both sexes       All ages  Number of divorces
# 1971  Ontario         Males       All ages  Number of divorces
# ...       ...           ...            ...                 ...
# 2017  Ontario         Males       All ages  Number of divorces
# 2017  Ontario       Females       All ages  Number of divorces
# 2018  Ontario    Both sexes       All ages  Number of divorces
# 2019  Ontario    Both sexes       All ages  Number of divorces
# 2020  Ontario    Both sexes       All ages  Number of divorces
#
#      Unit Of Measure    VALUE
# Year
# 1970          Number  24012.0
# 1970          Number  12006.0
# 1970          Number  12006.0
# 1971          Number  24609.0
# 1971          Number  12306.0
# ...

# %%
Ontario_divorced_df=Ontario_divorced_df2[Ontario_divorced_df2['Sex or gender'].str.contains('^Both sexes$')]
Ontario_divorced_df
# Out:
#      Location Sex or gender Age at divorce           Indicator  \
# Year
# 1970  Ontario    Both sexes       All ages  Number of divorces
# 1971  Ontario    Both sexes       All ages  Number of divorces
# 1972  Ontario    Both sexes       All ages  Number of divorces
# 1973  Ontario    Both sexes       All ages  Number of divorces
# 1974  Ontario    Both sexes       All ages  Number of divorces
# 1975  Ontario    Both sexes       All ages  Number of divorces
# 1976  Ontario    Both sexes       All ages  Number of divorces
# 1977  Ontario    Both sexes       All ages  Number of divorces
# 1978  Ontario    Both sexes       All ages  Number of divorces
# 1979  Ontario    Both sexes       All ages  Number of divorces
# 1980  Ontario    Both sexes       All ages  Number of divorces
# 1981  Ontario    Both sexes       All ages  Number of divorces
# 1982  Ontario    Both sexes       All ages  Number of divorces
# 1983  Ontario    Both sexes       All ages  Number of divorces
# ...

# %%
print(f'The year with the most number of divorces is {Ontario_divorced_df["VALUE"].idxmax()}, with {round(Ontario_divorced_df["VALUE"].max())} divorces')
print(f'The year with the least number of divorces is {Ontario_divorced_df["VALUE"].idxmin()} with {round(Ontario_divorced_df["VALUE"].min())} divorces')
# Out:
# The year with the most number of divorces is 1987, with 78870 divorces
# The year with the least number of divorces is 1970 with 24012 divorces

# %%
Ontario_divorced_df.to_csv(r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Cleaned_Datasets\Ontario_Number_of_Divorces.csv",
                    encoding="Utf-8", index=True, header=True)

# %% [markdown]
# ## 3rd Dataset to clean...Renters

# %%
rentersfilepath=r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Renters - 39100039-eng\39100039.csv"
renters_df=pd.read_csv(rentersfilepath)
renters_df.head()
# Out:
#    REF_DATE                        GEO DGUID   Occupancy status      UOM  \
# 0      1996                     Canada    00  Total, households  Percent
# 1      1996                     Canada    00            Renters  Percent
# 2      1996                     Canada    00             Owners  Percent
# 3      1996  Newfoundland and Labrador    10  Total, households  Percent
# 4      1996  Newfoundland and Labrador    10            Renters  Percent
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE  VALUE STATUS  \
# 0     239        units           0  v4299273         1.1   26.5    NaN
# 1     239        units           0  v4299274         1.2   43.0    NaN
# 2     239        units           0  v4299275         1.3   16.9    NaN
# 3     239        units           0  v4299276         2.1   19.1    NaN
# 4     239        units           0  v4299277         2.2   43.2    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1
# ...

# %%
renters_df['REF_DATE'].unique()
# Out:
# array([1996], dtype=int64)

# %%
renters_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Occupancy status', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
renamerenters=renters_df.rename(columns={'REF_DATE':'Year', 'GEO':'Location', 'UOM':'Unit Of Measure'})
renamerenters.sample()
# Out:
#      Year                                    Location DGUID  \
# 377  1996  Chinook Regional Health Authority, Alberta  4801
#
#       Occupancy status Unit Of Measure  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 377  Total, households         Percent     239        units           0
#
#        VECTOR  COORDINATE  VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 377  v4299650       128.1   19.9    NaN     NaN         NaN         1

# %%
newrentersdf=renamerenters.set_index('Year')
newrentersdf.head()
# Out:
#                        Location DGUID   Occupancy status Unit Of Measure  \
# Year
# 1996                     Canada    00  Total, households         Percent
# 1996                     Canada    00            Renters         Percent
# 1996                     Canada    00             Owners         Percent
# 1996  Newfoundland and Labrador    10  Total, households         Percent
# 1996  Newfoundland and Labrador    10            Renters         Percent
#
#       UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE  VALUE STATUS  \
# Year
# 1996     239        units           0  v4299273         1.1   26.5    NaN
# 1996     239        units           0  v4299274         1.2   43.0    NaN
# 1996     239        units           0  v4299275         1.3   16.9    NaN
# 1996     239        units           0  v4299276         2.1   19.1    NaN
# 1996     239        units           0  v4299277         2.2   43.2    NaN
#
#       SYMBOL  TERMINATED  DECIMALS
# Year
# ...

# %%
filtered_rentersdf=newrentersdf.loc[:,['Location','Occupancy status','Unit Of Measure', 'VALUE' ]]
filtered_rentersdf
# Out:
#                        Location   Occupancy status Unit Of Measure  VALUE
# Year
# 1996                     Canada  Total, households         Percent   26.5
# 1996                     Canada            Renters         Percent   43.0
# 1996                     Canada             Owners         Percent   16.9
# 1996  Newfoundland and Labrador  Total, households         Percent   19.1
# 1996  Newfoundland and Labrador            Renters         Percent   43.2
# ...                         ...                ...             ...    ...
# 1996                    Nunavut            Renters         Percent    7.4
# 1996                    Nunavut             Owners         Percent    8.6
# 1996                    Nunavut  Total, households         Percent    7.6
# 1996                    Nunavut            Renters         Percent    7.4
# 1996                    Nunavut             Owners         Percent    8.6
#
# [515 rows x 4 columns]

# %%
filtered_rentersdf['Location'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador',
#        "Health and Community Services St. John's Region, Newfoundland and Labrador",
#        'Health and Community Services Eastern Region, Newfoundland and Labrador',
#        'Health and Community Services Central Region, Newfoundland and Labrador',
#        'Health and Community Services Western Region, Newfoundland and Labrador',
#        'Grenfell Regional Health Services Board, Newfoundland and Labrador',
#        'Health Labrador Corporation, Newfoundland and Labrador',
#        'Prince Edward Island',
#        'Urban Health Region, Prince Edward Island',
#        'Rural Health Region, Prince Edward Island', 'Nova Scotia',
#        'Zone 1, Nova Scotia', 'Zone 2, Nova Scotia',
#        'Zone 3, Nova Scotia', 'Zone 4, Nova Scotia',
#        'Zone 5, Nova Scotia', 'Zone 6, Nova Scotia', 'New Brunswick',
#        'Region 1, New Brunswick', 'Region 2, New Brunswick',
#        'Region 3, New Brunswick', 'Region 4, New Brunswick',
# ...

# %%
Ontario_rentersdf=filtered_rentersdf[filtered_rentersdf['Location'].str.contains('Ontario')]
Ontario_rentersdf
# Out:
#                                         Location   Occupancy status  \
# Year
# 1996          Ontario by District Health Council  Total, households
# 1996          Ontario by District Health Council            Renters
# 1996          Ontario by District Health Council             Owners
# 1996  Champlain District Health Council, Ontario  Total, households
# 1996  Champlain District Health Council, Ontario            Renters
# ...                                          ...                ...
# 1996            York Public Health Unit, Ontario            Renters
# 1996            York Public Health Unit, Ontario             Owners
# 1996         Toronto Public Health Unit, Ontario  Total, households
# 1996         Toronto Public Health Unit, Ontario            Renters
# 1996         Toronto Public Health Unit, Ontario             Owners
#
#      Unit Of Measure  VALUE
# Year
# 1996         Percent   28.0
# 1996         Percent   44.2
# 1996         Percent   18.9
# ...

# %%
Ontario_rentersdf.to_csv(r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\Cleaned_Datasets\Ontario_Renters.csv",
                    encoding="Utf-8", index=True, header=True)

# %% [markdown]
# ## Cleaned Dataset .... Husband/Wife Earnings

# %%
dffilepath=r"C:\Users\Eleshia\Desktop\DA Boot Camp\Renters-Anonymous\EarningsWifeHusband11100146-eng\11100146.csv"
df4=pd.read_csv(dffilepath)
df4
# Out:
#        REF_DATE                           GEO DGUID  \
# 0          1976                        Canada   NaN
# 1          1976                        Canada   NaN
# 2          1976                        Canada   NaN
# 3          1976                        Canada   NaN
# 4          1976                        Canada   NaN
# ...         ...                           ...   ...
# 36795      2011  All other non-selected areas   NaN
# 36796      2011  All other non-selected areas   NaN
# 36797      2011  All other non-selected areas   NaN
# 36798      2011  All other non-selected areas   NaN
# 36799      2011  All other non-selected areas   NaN
#
#                                 Statistics  \
# 0      Percentage of husband-wife families
# 1      Percentage of husband-wife families
# 2      Percentage of husband-wife families
# 3      Percentage of husband-wife families
# 4      Percentage of husband-wife families
# ...                                    ...
# ...

# %%
df4.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Statistics', 'Husband-wife families',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
new_hw_df=df4.rename(columns={'REF_DATE':'Year', 'GEO':'Location', 'UOM':'Unit Of Measure'})
new_hw_df.sample()
# Out:
#        Year         Location  DGUID                   Statistics  \
# 30901  2006  London, Ontario  35555  Average total family income
#
#                              Husband-wife families        Unit Of Measure  \
# 30901  Single-earner families, husband sole earner  2011 constant dollars
#
#        UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS  \
# 30901     389        units           0  v25699285     22.3.6  71900.0      C
#
#        SYMBOL  TERMINATED  DECIMALS
# 30901     NaN         NaN         0

# %%
# new_hw_df=rename_husband_wife_earn.set_index('Year')
# new_hw_df.head()

# %%
filtered_hwdf=new_hw_df.loc[:,['Year','Location','Statistics', 'Husband-wife families','Unit Of Measure', 'VALUE' ]]
filtered_hwdf
# Out:
#        Year                      Location  \
# 0      1976                        Canada
# 1      1976                        Canada
# 2      1976                        Canada
# 3      1976                        Canada
# 4      1976                        Canada
# ...     ...                           ...
# 36795  2011  All other non-selected areas
# 36796  2011  All other non-selected areas
# 36797  2011  All other non-selected areas
# 36798  2011  All other non-selected areas
# 36799  2011  All other non-selected areas
#
#                                 Statistics  \
# 0      Percentage of husband-wife families
# 1      Percentage of husband-wife families
# 2      Percentage of husband-wife families
# 3      Percentage of husband-wife families
# 4      Percentage of husband-wife families
# ...                                    ...
# 36795           Median total family income
# 36796           Median total family income
# 36797           Median total family income
# ...

# %%
filtered_hwdf['Location'].unique()
# Out:
# array(['Canada', 'Atlantic provinces', 'Newfoundland and Labrador',
#        'Prince Edward Island', 'Nova Scotia', 'New Brunswick', 'Quebec',
#        'Ontario', 'Prairie provinces', 'Manitoba', 'Saskatchewan',
#        'Alberta', 'British Columbia',
#        'Total selected census metropolitan areas', 'Halifax, Nova Scotia',
#        'Québec, Quebec', 'Montréal, Quebec',
#        'Ottawa-Gatineau, Ontario/Quebec', 'Toronto, Ontario',
#        'Hamilton, Ontario', 'St. Catharines-Niagara, Ontario',
#        'Kitchener-Cambridge-Waterloo, Ontario', 'London, Ontario',
#        'Windsor, Ontario', 'Winnipeg, Manitoba', 'Calgary, Alberta',
#        'Edmonton, Alberta', 'Vancouver, British Columbia',
#        'Victoria, British Columbia', 'All other non-selected areas',
#        "St. John's, Newfoundland and Labrador", 'Sherbrooke, Quebec',
#        'Oshawa, Ontario', 'Regina, Saskatchewan',
#        'Saskatoon, Saskatchewan'], dtype=object)

# %%
filtered_hwdf['Statistics'].unique()
# Out:
# array(['Percentage of husband-wife families',
#        'Number of husband-wife families', 'Average total family income',
#        'Median total family income'], dtype=object)

# %%
filtered_hwdf['Husband-wife families'].unique()
# Out:
# array(['All husband-wife families', 'Total dual-earner families',
#        'Dual-earner families, wife earned more than husband',
#        'Dual-earner families, wife earned less than husband',
#        'Total single-earner families',
#        'Single-earner families, husband sole earner',
#        'Single-earner families, wife sole earner',
#        'Neither spouse had earnings'], dtype=object)

# %%
Ontario_hwdf1=filtered_hwdf[filtered_hwdf['Location'].str.contains('^Ontario$')]
Ontario_hwdf1
# Out:
#        Year Location                           Statistics  \
# 224    1976  Ontario  Percentage of husband-wife families
# 225    1976  Ontario  Percentage of husband-wife families
# 226    1976  Ontario  Percentage of husband-wife families
# 227    1976  Ontario  Percentage of husband-wife families
# 228    1976  Ontario  Percentage of husband-wife families
# ...     ...      ...                                  ...
# 35931  2011  Ontario           Median total family income
# 35932  2011  Ontario           Median total family income
# 35933  2011  Ontario           Median total family income
# 35934  2011  Ontario           Median total family income
# 35935  2011  Ontario           Median total family income
#
#                                    Husband-wife families  \
# 224                            All husband-wife families
# 225                           Total dual-earner families
# 226    Dual-earner families, wife earned more than hu...
# ...

